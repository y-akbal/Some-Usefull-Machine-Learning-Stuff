# %%
import gymnasium
gymnasium.make("InvertedDoublePendulum-v4")
# Out:
# You appear to be missing MuJoCo.  We expected to find the file here: /home/sahmaran/.mujoco/mujoco210
#
# This package only provides python bindings, the library must be installed separately.
#
# Please follow the instructions on the README to install MuJoCo
#
#     https://github.com/openai/mujoco-py#install-mujoco
#
# Which can be downloaded from the website
#
#     https://www.roboti.us/index.html
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 import gymnasium
# ----> 2 gymnasium.make("InvertedDoublePendulum-v4")
#
# File ~/anaconda3/envs/torch/lib/python3.10/site-packages/gymnasium/envs/registration.py:756, in make(id, max_episode_steps, autoreset, apply_api_compatibility, disable_env_checker, **kwargs)
#     753     env_creator = env_spec.entry_point
#     754 else:
#     755     # Assume it's a string
# ...
